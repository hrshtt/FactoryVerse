# %%
from src.FactoryVerse.dsl.types import *

# %%
props = PrototypeProperties("./factorio-data-dump.json")

# %%
[item for item in dir(props) if "__" not in item]
# Out:
# ['apply_vector',
#  'burner_mining_drill',
#  'data',
#  'electric_mining_drill',
#  'inserter',
#  'long_handed_inserter',
#  'pumpjack',
#  'transport_belt']

# %%
props.electric_mining_drill.get_resource_bbox(MapPosition(10,10))
# Out:
# BoundingBox(left_top=Position(x=7.51, y=7.51), right_bottom=Position(x=12.49, y=12.49), orientation=None)

# %%
props.electric_mining_drill.output_position(MapPosition(10,10), Direction.NORTH)
# Out:
# MapPosition(x=10, y=8.15)

# %%
props.pumpjack.get_raw()
# Out:
# {'type': 'mining-drill',
#  'name': 'pumpjack',
#  'flags': ['placeable-neutral', 'player-creation'],
#  'minable': {'mining_time': 0.5, 'result': 'pumpjack'},
#  'resource_categories': ['basic-fluid'],
#  'max_health': 200,
#  'collision_box': [[-1.2, -1.2], [1.2, 1.2]],
#  'selection_box': [[-1.5, -1.5], [1.5, 1.5]],
#  'drawing_box_vertical_extension': 1,
#  'energy_source': {'type': 'electric',
#   'emissions_per_minute': {'pollution': 10},
#   'usage_priority': 'secondary-input'},
#  'output_fluid_box': {'volume': 1000,
#   'pipe_connections': [{'direction': 0,
#     'positions': [[1, -1], [1, -1], [-1, 1], [-1, 1]],
#     'flow_direction': 'output'}]},
#  'energy_usage': '90kW',
#  'mining_speed': 1,
#  'resource_searching_radius': 0.49000000000000005,
#  'vector_to_place_result': [0, 0],
#  'module_slots': 2,
#  'base_render_layer': 'object',
#  'fast_replaceable_group': 'pumpjack',
#  'circuit_connector': [{'points': {'wire': {'red': [0.34375, -0.859375],
# ...

# %%
props.long_handed_inserter.get_raw()
# Out:
# {'type': 'inserter',
#  'name': 'long-handed-inserter',
#  'flags': ['placeable-neutral', 'placeable-player', 'player-creation'],
#  'minable': {'mining_time': 0.1, 'result': 'long-handed-inserter'},
#  'max_health': 160,
#  'resistances': [{'type': 'fire', 'percent': 90}],
#  'collision_box': [[-0.15, -0.15], [0.15, 0.15]],
#  'selection_box': [[-0.4, -0.35], [0.4, 0.45]],
#  'starting_distance': 1.7,
#  'pickup_position': [0, -2],
#  'insert_position': [0, 2.2],
#  'energy_per_movement': '5kJ',
#  'energy_per_rotation': '5kJ',
#  'extension_speed': 0.05,
#  'rotation_speed': 0.02,
#  'filter_count': 5,
#  'hand_size': 1.5,
#  'energy_source': {'type': 'electric',
#   'usage_priority': 'secondary-input',
#   'drain': '0.4kW'},
#  'fast_replaceable_group': 'long-handed-inserter',
#  'impact_category': 'metal',
#  'circuit_connector': [{'points': {'wire': {'red': [0.515625, 0.109375],
#      'green': [0.390625, 0.25]}}},
#   {'points': {'wire': {'red': [-0.171875, -0.328125],
# ...
